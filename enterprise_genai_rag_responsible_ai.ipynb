# %% [markdown]
# # Enterprise GenAI RAG Assistant — Retrieval, Evaluation & Responsible AI
#
# Independent portfolio project over two public Accenture 2025 reports.
#
# **Frozen project results from the documented run:** dense Hit@1 60% → hybrid Hit@1 90%; hybrid Hit@3 100%; MRR@10 0.950; 5/5 unsupported/adversarial questions refused; 20% false-refusal rate on answerable questions.
#
# Use a **T4 GPU** (or another CUDA GPU) in Colab before running the generation stage. The source PDFs are downloaded from official public URLs at runtime.

# %% [markdown]
# ## 1. Prepare the repository and dependencies

# %%
import os

if not os.path.exists('src/rag_pipeline.py'):
    # !git clone -q https://github.com/Prasanna-K-123/enterprise-genai-rag-responsible-ai.git
    # %cd enterprise-genai-rag-responsible-ai

# !pip -q install -r requirements.txt
print('Environment ready.')

# %% [markdown]
# ## 2. Run the reproducible pipeline
#
# This executes ingestion, chunking, dense and hybrid retrieval, the frozen retrieval benchmark, Qwen2.5-3B structured generation, refusal controls, and the frozen end-to-end evaluation.

# %%
# %run src/rag_pipeline.py

# %% [markdown]
# ## Interpretation
#
# The project deliberately keeps known limitations visible. Automated citation validity is not the same as semantic grounding; see `results/manual_claim_summary.csv` and `results/manual_grounding_review.csv` for the documented manual audit.
